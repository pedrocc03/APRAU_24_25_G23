# %% [markdown]
# # **Aprendizagem Automática (APRAU)**
#
# ### Trabalho - etapa 1

# %% [markdown]
# ### Features:
#
# * **Altitude**: A altitude do terreno em metros.
# * **Slope_Orientation (Orientação da Inclinação)**: A direção da bússola para a qual o terreno está voltado (em graus).
# * **Slope (Inclinação)**: A inclinação em graus.
# * **Horizontal_Distance_To_Water (Distância Horizontal até a Água)**: Distância horizontal até a superfície de água mais próxima (em metros).
# * **Vertical_Distance_To_Water (Distância Vertical até a Água)**: Distância vertical até a superfície de água mais próxima (em metros).
# * **Horizontal_Distance_To_Roadways (Distância Horizontal até Estradas)**: Distância horizontal até a estrada mais próxima, em metros (pode indicar influência de atividades humanas no ambiente).
# * **Shadow_Index (Índice de Sombra)**: Índice de sombra medido em três horários do dia (9h, 12h e 15h).
# * **Horizontal_Distance_To_Fire_Points (Distância Horizontal até Pontos de Fogo)**: Distância horizontal até os pontos de ignição de incêndios mais próximos (em metros).
# * **Canopy_Density (Densidade do Dossel)**: A percentagem da área do terreno coberta por dossel de árvores (medido em percentagem, de 0 a 100).
# * **Rainfall_Summer (Precipitação no Verão)**: Precipitação média durante o verão (medida em mm).
# * **Rainfall_Winter (Precipitação no Inverno)**: Precipitação média durante o inverno (medida em mm).
# * **Wind_Exposure_Level (Nível de Exposição ao Vento)**: Velocidade média do vento durante o inverno (medida em km/h).
# * **Soil_Type (Tipo de Solo)**: Designação do tipo de solo. No conjunto de dados existem 40 tipos diferentes de solo.
# * **Wilderness_Area (Área Selvagem)**: No conjunto de dados existem 4 tipos diferentes de áreas selvagens.
# * **Vegetation_Type (Tipo de Vegetação)**: A variável alvo. Existem 7 classes possíveis, cada uma representando um tipo diferente de vegetação.

# %% [markdown]
# ## Bibliotecas base

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Carregar dados

# %% [markdown]
# ### 1. Data_Class_2

# %%
df_class_2 = pd.read_csv('Data_Class_2.csv')
df_class_2.shape
# Out:
# (1404, 18)

# %%
df_class_2.head()
# Out:
#       Id  Altitude  Slope_Orientation  Slope  Horizontal_Distance_To_Water  \
# 0  14537      3166                198      6                           192
# 1   1154      2877                342     13                           450
# 2  14507      3103                 48      7                             0
# 3   7196      2950                269     39                           450
# 4   1801      2868                332     17                            60
#
#    Vertical_Distance_To_Water  Horizontal_Distance_To_Roadways  \
# 0                          -4                             3137
# 1                         131                              618
# 2                           0                             1034
# 3                         316                             1528
# 4                          23                             1718
#
#    Shadow_Index_9h  Shadow_Index_12h  Shadow_Index_15h  \
# 0              218               245               163
# ...

# %% [markdown]
# ### 2. Data_Class_5

# %%
df_class_5 = pd.read_csv('Data_Class_5.csv')
df_class_5.shape
# Out:
# (1944, 18)

# %%
df_class_5.head()
# Out:
#       Id  Altitude  Slope_Orientation  Slope  Horizontal_Distance_To_Water  \
# 0   7985      2567                 99      6                           379
# 1  13500      2789                 58      7                           551
# 2  11569      2739                 91     10                            30
# 3  13803      2887                332     12                           607
# 4   3113      2872                225     18                           285
#
#    Vertical_Distance_To_Water  Horizontal_Distance_To_Roadways  \
# 0                          25                             1253
# 1                          55                              240
# 2                           4                             1398
# 3                         121                             2201
# 4                          37                             1077
#
#    Shadow_Index_9h  Shadow_Index_12h  Shadow_Index_15h  \
# 0              230               232               136
# ...

# %% [markdown]
# ### 3. Data_Class_6

# %%
df_class_6 = pd.read_csv('Data_Class_6.csv')
df_class_6.shape
# Out:
# (2160, 18)

# %%
df_class_6.head()
# Out:
#      Id  Altitude  Slope_Orientation  Slope  Horizontal_Distance_To_Water  \
# 0  1869      2446                 23      8                             0
# 1  1881      2508                 20     21                             0
# 2  1882      2437                349     12                            30
# 3  1889      2515                323     24                            42
# 4  1890      2533                322     29                            85
#
#    Vertical_Distance_To_Water  Horizontal_Distance_To_Roadways  \
# 0                           0                              443
# 1                           0                              859
# 2                           4                              997
# 3                          15                              866
# 4                          36                              828
#
#    Shadow_Index_9h  Shadow_Index_12h  Shadow_Index_15h  \
# 0              216               223               144
# ...

# %% [markdown]
# ## Análise Exploratória

# %% [markdown]
# ### Estatísticas descritivas

# %%
df_class_2.describe()
# Out:
#                  Id     Altitude  Slope_Orientation        Slope  \
# count   1404.000000  1404.000000        1404.000000  1404.000000
# mean    6122.415242  2919.164530         152.111111    13.413105
# std     5062.550238   184.577202         107.033400     7.003329
# min        3.000000  2236.000000           0.000000     1.000000
# 25%      815.500000  2796.750000          61.000000     8.000000
# 50%     6658.500000  2923.000000         127.000000    13.000000
# 75%    10746.000000  3037.000000         239.250000    17.000000
# max    14930.000000  3413.000000         359.000000    45.000000
#
#        Horizontal_Distance_To_Water  Vertical_Distance_To_Water  \
# count                   1404.000000                 1404.000000
# mean                     287.415242                   47.106125
# std                      211.061558                   58.508592
# min                        0.000000                 -146.000000
# ...

# %%
df_class_5.describe()
# Out:
#                  Id     Altitude  Slope_Orientation        Slope  \
# count   1944.000000  1944.000000        1944.000000  1944.000000
# mean    6477.716049  2785.611626         138.122942    16.704218
# std     4548.424456    96.535818          91.900698     8.444330
# min        1.000000  2482.000000           0.000000     1.000000
# 25%     2115.750000  2729.000000          69.000000    10.000000
# 50%     6688.500000  2792.500000         108.000000    16.000000
# 75%    10649.250000  2854.000000         192.000000    22.000000
# max    14849.000000  3007.000000         359.000000    50.000000
#
#        Horizontal_Distance_To_Water  Vertical_Distance_To_Water  \
# count                   1944.000000                 1944.000000
# mean                     207.278292                   50.511317
# std                      177.317201                   57.657898
# min                        0.000000                 -114.000000
# ...

# %%
df_class_6.describe()
# Out:
#                  Id     Altitude  Slope_Orientation        Slope  \
# count   2160.000000  2160.000000        2160.000000  2160.000000
# mean    8061.305093  2423.276852         180.617130    18.986111
# std     3949.174092   188.966981         133.087862     7.714618
# min     1869.000000  1863.000000           0.000000     1.000000
# 25%     5275.750000  2319.750000          44.000000    13.000000
# 50%     7164.500000  2430.000000         171.000000    19.000000
# 75%    11470.500000  2553.000000         318.000000    24.000000
# max    15113.000000  2883.000000         360.000000    52.000000
#
#        Horizontal_Distance_To_Water  Vertical_Distance_To_Water  \
# count                   2160.000000                 2160.000000
# mean                     160.095370                   44.873611
# std                      125.770515                   47.034674
# min                        0.000000                 -104.000000
# ...

# %%
df_all = pd.concat([df_class_2,df_class_5,df_class_6], axis=0)
df_all.head()
# Out:
#       Id  Altitude  Slope_Orientation  Slope  Horizontal_Distance_To_Water  \
# 0  14537      3166                198      6                           192
# 1   1154      2877                342     13                           450
# 2  14507      3103                 48      7                             0
# 3   7196      2950                269     39                           450
# 4   1801      2868                332     17                            60
#
#    Vertical_Distance_To_Water  Horizontal_Distance_To_Roadways  \
# 0                          -4                             3137
# 1                         131                              618
# 2                           0                             1034
# 3                         316                             1528
# 4                          23                             1718
#
#    Shadow_Index_9h  Shadow_Index_12h  Shadow_Index_15h  \
# 0              218               245               163
# ...

# %%
df_all.shape
# Out:
# (5508, 18)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5508 entries, 0 to 2159
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Id                                  5508 non-null   int64
#  1   Altitude                            5508 non-null   int64
#  2   Slope_Orientation                   5508 non-null   int64
#  3   Slope                               5508 non-null   int64
#  4   Horizontal_Distance_To_Water        5508 non-null   int64
#  5   Vertical_Distance_To_Water          5508 non-null   int64
#  6   Horizontal_Distance_To_Roadways     5508 non-null   int64
#  7   Shadow_Index_9h                     5508 non-null   int64
#  8   Shadow_Index_12h                    5508 non-null   int64
#  9   Shadow_Index_15h                    5508 non-null   int64
#  10  Horizontal_Distance_To_Fire_Points  5508 non-null   int64
# ...

# %%
df_all.nunique()
# Out:
# Id                                    5508
# Altitude                              1192
# Slope_Orientation                      361
# Slope                                   49
# Horizontal_Distance_To_Water           256
# Vertical_Distance_To_Water             335
# Horizontal_Distance_To_Roadways       1856
# Shadow_Index_9h                        154
# Shadow_Index_12h                       130
# Shadow_Index_15h                       231
# Horizontal_Distance_To_Fire_Points    1732
# Canopy_Density                        3602
# Rainfall_Summer                       5028
# Rainfall_Winter                       5377
# Wind_Exposure_Level                   3579
# Soil_Type                               35
# Wilderness_Area                          4
# Vegetation_Type                          3
# dtype: int64

# %%
df_all = df_all.drop(['Id'],axis=1)

# %%
# Função para verificar NaNs e Outliers
def check_nans_outliers(df, class_name):
    print(f"Análise de NaNs e Outliers para {class_name}")
    
    # Filtrar para a classe objetivo
    df_class = df[df['Vegetation_Type'] == class_name] 
    
    # Verificar NaNs
    print(f"\n{class_name} - Verificação de NaNs:")
    print(df_class.isnull().sum())
    
    # Selecionar apenas colunas numéricas
    df_numeric = df_class.select_dtypes(include=[np.number])
    
    # Análise de Outliers
    print(f"\n{class_name} - Outliers (nas colunas numéricas):")
    Q1 = df_numeric.quantile(0.25)
    Q3 = df_numeric.quantile(0.75)
    IQR = Q3 - Q1
    outliers = ((df_numeric < (Q1 - 1.5 * IQR)) | (df_numeric > (Q3 + 1.5 * IQR)))
    
    # Mostrar o número de outliers em cada coluna
    print(outliers.sum())

# Verificação de NaNs e Outliers para as 3 classes
for class_name in df_all['Vegetation_Type'].unique():
    check_nans_outliers(df_all, class_name)
# Out:
# Análise de NaNs e Outliers para Type_2
#
# Type_2 - Verificação de NaNs:
# Altitude                              0
# Slope_Orientation                     0
# Slope                                 0
# Horizontal_Distance_To_Water          0
# Vertical_Distance_To_Water            0
# Horizontal_Distance_To_Roadways       0
# Shadow_Index_9h                       0
# Shadow_Index_12h                      0
# Shadow_Index_15h                      0
# Horizontal_Distance_To_Fire_Points    0
# Canopy_Density                        0
# Rainfall_Summer                       0
# Rainfall_Winter                       0
# Wind_Exposure_Level                   0
# Soil_Type                             0
# Wilderness_Area                       0
# Vegetation_Type                       0
# dtype: int64
#
# Type_2 - Outliers (nas colunas numéricas):
# Altitude                               5
# Slope_Orientation                      0
# Slope                                 32
# ...

# %%
numericFeatures = list(df_all.select_dtypes(include=[np.number]).columns)

# %%
rows = 10
colunms = 2

plt.figure(figsize=(25, 70))
 
for i, features in enumerate(numericFeatures):
    
    plt.subplot(rows, colunms, i+1)
    sns.boxplot(data=df_all, x='Vegetation_Type', y=features, palette="bright")

plt.tight_layout()
plt.show()

# %%
def remover_outliers(df, atributo_objetivo, atributo_preditivo):
    # Criação de uma cópia do dataset 
    df_sem_outliers = df.copy()

    for classe in atributo_objetivo:
        for coluna in atributo_preditivo:
            # Cálculo dos limites para identificar outliers
            Q1 = df_sem_outliers[df_sem_outliers['Vegetation_Type'] == classe][coluna].quantile(0.25)
            Q3 = df_sem_outliers[df_sem_outliers['Vegetation_Type'] == classe][coluna].quantile(0.75)
            IQR = Q3 - Q1

            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR

            # Identificação e remoção dos outliers
            outliers = (df_sem_outliers['Vegetation_Type'] == classe) & ((df_sem_outliers[coluna] < lower_bound) | (df_sem_outliers[coluna] > upper_bound))
            df_sem_outliers = df_sem_outliers[~outliers]
            
    # Returno do dataset sem outliers
    return df_sem_outliers

# %%
# Classes objetivo
atributo_objetivo = ['Type_2', 'Type_5', 'Type_6']

# Aplicação da função para remover os outliers das combinações da classe objetivo e atributos preditivos
df_all_sem_outliers = remover_outliers(df_all, atributo_objetivo, numericFeatures)

# %%
rows = 10
colunms = 2

plt.figure(figsize=(25, 70))
 
for i, features in enumerate(numericFeatures):

    plt.subplot(rows, colunms, i+1)
    sns.boxplot(data=df_all_sem_outliers, x='Vegetation_Type', y=features, palette="bright")

plt.tight_layout()
plt.show()

# %%
df_all_sem_outliers.shape
# Out:
# (4729, 17)

# %%
df_all_sem_outliers.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-info">
# Verificou-se uma redução significativa dos outliers.
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-around;" class="alert alert-block alert-info">
#     <div style="width: 30%;">
#         <strong>Type_2</strong>
#         <p>Outliers nas caraterísticas:</p>
#         <ul>
#             <li>Altitude</li>
#             <li>Slope</li>
#             <li>Horizontal_Distance_To_Water</li>
#             <li>Vertical_Distance_To_Water</li>
#             <li>Shadow_Index_9h</li>
#             <li>Shadow_Index_12h</li>
#             <li>Shadow_Index_15h</li>
#             <li>Horizontal_Distance_To_Fire_Points</li>
#         </ul>
#     </div>
#     <div style="width: 30%;">
#         <strong>Type_5</strong>
#         <p>Outliers nas caraterísticas:</p>
#         <ul>
#             <li>Altitude</li>
#             <li>Slope</li>
#             <li>Horizontal_Distance_To_Water</li>
#             <li>Vertical_Distance_To_Water</li>
#             <li>Horizontal_Distance_To_Roadways</li>
#             <li>Shadow_Index_9h</li>
#             <li>Shadow_Index_12h</li>
#             <li>Horizontal_Distance_To_Fire_Points</li>
#         </ul>
#     </div>
#     <div style="width: 30%;">
#         <strong>Type_6</strong>
#         <p>Outliers nas caraterísticas:</p>
#         <ul>
#             <li>Altitude</li>
#             <li>Slope</li>
#             <li>Horizontal_Distance_To_Water</li>
#             <li>Vertical_Distance_To_Water</li>
#             <li>Horizontal_Distance_To_Roadways</li>
#             <li>Shadow_Index_9h</li>
#             <li>Shadow_Index_12h</li>
#             <li>Horizontal_Distance_To_Fire_Points</li>
#         </ul>
#     </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Manter:</b>
# Estes outliers podem ser medições reais, como condições extremas do terreno (muito íngreme, muito distante de corpos de água ou estradas) ou diferentes zonas de vegetação que estão naturalmente em áreas mais extremas.
# </div>

# %% [markdown]
# ### Análise Univariada

# %%
from sklearn.preprocessing import LabelEncoder

# Criar uma cópia do DataFrame
df_encoded = df_all.copy()

label_encoder = LabelEncoder()

# Lista de variáveis categóricas
categoricalFeatures = ['Vegetation_Type', 'Soil_Type', 'Wilderness_Area']

# Aplicar o LabelEncoder em cada variável categórica
for feature in categoricalFeatures:
    df_encoded[feature] = label_encoder.fit_transform(df_encoded[feature])

# Nova lista de variáveis numéricas, incluindo as categóricas agora codificadas
numericFeatures_encoder = list(df_encoded.select_dtypes(include=[np.number]).columns)

# %%
# Verificação da distribuição de cada atributo, através de Histograma

plt.figure(figsize=(12, 40)) 

n_rows = 10
n_cols = 2

# Loop para gerar gráficos para variáveis numéricas e categóricas
for i, feature in enumerate(numericFeatures_encoder):
    plt.subplot(n_rows, n_cols, i + 1)
    
    # Verificar se a variável é categórica ou numérica
    if feature in categoricalFeatures:
        # Gráfico de barras para variáveis categóricas
        sns.countplot(data=df_encoded, x=feature, palette="bright")
        plt.title(f"Distribuição de {feature} (Categórica)")
    else:
        # Histograma para variáveis numéricas
        sns.histplot(data=df_encoded, x=feature, kde=True, common_norm=False, palette="bright")
        plt.title(f"Distribuição de {feature} (Numérica)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análise Bivariada

# %%
# Verificação da distribuição de cada classe do atributo objetivo 
# relativamente a cada atributo preditivo

n_rows = 10 
n_cols = 2

# Definir o tamanho da figura
plt.figure(figsize=(12, 40))

# Loop para gerar gráficos bivariados para todas as variáveis
for i, feature in enumerate(numericFeatures_encoder):
    plt.subplot(n_rows, n_cols, i + 1)
    
    # Verificar se a variável é categórica ou numérica
    if feature in categoricalFeatures:
        # Gráfico de barras para variáveis categóricas com hue
        sns.countplot(data=df_all, x=feature, hue='Vegetation_Type', palette="bright")
        plt.title(f"Distribuição de {feature} por Vegetation_Type (Categórica)")
    else:
        # Histograma para variáveis numéricas com hue
        sns.histplot(data=df_all, x=feature, hue='Vegetation_Type', kde=True, common_norm=False, palette="bright")
        plt.title(f"Distribuição de {feature} por Vegetation_Type (Numérica)")

plt.tight_layout()
plt.show()

# %%
# Criar uma cópia do DataFrame
df_encoded = df_all.copy()

label_encoder = LabelEncoder()

# Lista de variáveis categóricas
categoricalFeatures = ['Vegetation_Type', 'Soil_Type', 'Wilderness_Area']

# Aplicar o LabelEncoder em cada variável categórica
for feature in categoricalFeatures:
    df_encoded[feature] = label_encoder.fit_transform(df_encoded[feature])

# Selecionar todas as variáveis numéricas, incluindo as categóricas agora codificadas
numericFeatures_encoder = df_encoded.select_dtypes(include=[np.number])

# Calcular a matriz de correlação entre os preditores
corr_matrix = numericFeatures_encoder.corr()

# Plotar o heatmap da matriz de correlação
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Matriz de Correlação entre os Preditores")
plt.show()

# %%
# Criar uma cópia do DataFrame
df_encoded = df_all.copy()

label_encoder = LabelEncoder()

# Codificar a variável objetivo 'Vegetation_Type'
df_encoded['Vegetation_Type_Encoded'] = label_encoder.fit_transform(df_encoded['Vegetation_Type'])

# Lista de variáveis categóricas (exceto a variável alvo, que já foi codificada)
categoricalFeatures = ['Soil_Type', 'Wilderness_Area']

# Aplicar o LabelEncoder nas variáveis categóricas restantes
for feature in categoricalFeatures:
    df_encoded[feature] = label_encoder.fit_transform(df_encoded[feature])

# Selecionar todas as variáveis numéricas, incluindo as categóricas agora codificadas
numericFeatures_encoder = df_encoded.select_dtypes(include=[np.number])

# Calcular a correlação dos preditores com a variável objetivo 'Vegetation_Type_Encoded'
corr_with_target = numericFeatures_encoder.corr()['Vegetation_Type_Encoded'].drop('Vegetation_Type_Encoded')

# Plotar o heatmap da correlação dos preditores com a variável objetivo
plt.figure(figsize=(8, 12))
sns.heatmap(corr_with_target.to_frame(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlação dos Preditores com Vegetation_Type")
plt.show()

# %% [markdown]
# ## Aplicação de Métodos
# #### Logistic Regression (LR), Linear Discriminant Analysis (LDA) and Quadratic Discriminant Analysis (QDA)

# %%
X = df_encoded.drop(columns=['Vegetation_Type', 'Vegetation_Type_Encoded'])
y = df_encoded['Vegetation_Type_Encoded']

# %% [markdown]
# #### Métodos: LR, LDA e QDA -> estes serão usados ao longo da implementação dos diferentes métodos de resampling

# %%
#Métodos: LR, LDA and QDA:
from sklearn.linear_model import LogisticRegression as LR
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA

# Logistic Regression
logrLR = LR(multi_class='ovr') # ovr -> One Versus Rest
 
# Linear Discriminant Analysis
logrLDA= LDA()

# Quadratic Discriminant Analysis
logrQDA = QDA()

# %% [markdown]
# ### Resampling Method: Holdout

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42, stratify=y)

#Verificar as condições no treino e teste 
print('Train size: ', X_train.shape)
print('Test size: ', X_test.shape)

# Converter os arrays NumPy para DataFrame para poder mostrar a distribuição da "Vegetation_Type" nos dados de treino e teste
df_train = pd.DataFrame({'condition': y_train})
df_test = pd.DataFrame({'condition': y_test})

# Exibir a distribuição das condições no treino e teste
print("\nTrain condition distribution:\n", df_train['condition'].value_counts(normalize=True))
print("\nTest condition distribution:\n", df_test['condition'].value_counts(normalize=True))
# Out:
# Train size:  (3855, 16)
# Test size:  (1653, 16)
#
# Train condition distribution:
#  condition
# 2    0.392218
# 1    0.352789
# 0    0.254994
# Name: proportion, dtype: float64
#
# Test condition distribution:
#  condition
# 2    0.392015
# 1    0.353297
# 0    0.254688
# Name: proportion, dtype: float64

# %% [markdown]
# ##### Neste caso, 70% dos dados são usados para treino (X_train e y_train), e 30% para teste (X_test e y_test). A estratificação é aplicada para garantir que a distribuição das classes seja mantida nos conjuntos de treino e teste, o que é particularmente útil, visto que, exite um desiquilibrio entre as classes.

# %% [markdown]
# #### Normalização dos dados

# %% [markdown]
# ##### A normalização dos dados é um passo fundamental em muitos casos, especialmente quando utilizamos algoritmos que são sensíveis à escala de variáveis. <br> Todas as variáveis são reescaladas para ter média 0 e desvio padrão 1. <br> No nosso caso ao usarmos LR, LDA e QDA, a normalização é recomendada, estes algoritmos beneficiam deste processo e resultam em previsões mais precisas e estáveis.

# %%
from sklearn.preprocessing import StandardScaler

# Inicializar o StandardScaler
scaler = StandardScaler()

#Normalizar o X de treino
Xstd_train = scaler.fit_transform(X_train)

#Normalizar o X de teste
Xstd_test = scaler.transform(X_test)

# %% [markdown]
# #### Avaliação do modelo

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Treinar os modelos
logrLR.fit(Xstd_train, y_train)
logrLDA.fit(Xstd_train, y_train)
logrQDA.fit(Xstd_train, y_train)

##########################LR##########################
# Previsões no conjunto de teste
y_pred_LR = logrLR.predict(Xstd_test)

# Avaliação do desempenho do modelo
classification_report_LR = classification_report(y_test, y_pred_LR)
confusion_matrix_LR = confusion_matrix(y_test, y_pred_LR, labels=[0, 1, 2])

# Converter a matriz para um DataFrame para mostrar classes
confusion_matrix_LR_df = pd.DataFrame(confusion_matrix_LR, 
                              index=['Type_2', 'Type_5', 'Type_6'], 
                              columns=['Pred_Type_2', 'Pred_Type_5', 'Pred_Type_6'])

print('\n############### Logistic Regression ###############')
print('Relatório de Classificação:\n', classification_report_LR)
print('Matriz de Confusão:\n', confusion_matrix_LR_df)

##########################LDA##########################
# Previsões no conjunto de teste
y_pred_LDA = logrLDA.predict(Xstd_test)

# Avaliação do desempenho do modelo
classification_report_LDA = classification_report(y_test, y_pred_LDA)
confusion_matrix_LDA = confusion_matrix(y_test, y_pred_LDA, labels=[0, 1, 2])

# Converter a matriz para um DataFrame para mostrar classes
confusion_matrix_LDA_df = pd.DataFrame(confusion_matrix_LDA, 
                              index=['Type_2', 'Type_5', 'Type_6'], 
                              columns=['Pred_Type_2', 'Pred_Type_5', 'Pred_Type_6'])

print('\n############### Linear Discriminant Analysis ###############')
print('Relatório de Classificação:\n', classification_report_LDA)
print('Matriz de Confusão:\n', confusion_matrix_LDA_df)

##########################QDA##########################
# Previsões no conjunto de teste
y_pred_QDA = logrQDA.predict(Xstd_test)

# Avaliação do desempenho do modelo
classification_report_QDA = classification_report(y_test, y_pred_QDA)
confusion_matrix_QDA = confusion_matrix(y_test, y_pred_QDA, labels=[0, 1, 2])

# Converter a matriz para um DataFrame para mostrar classes
confusion_matrix_QDA_df = pd.DataFrame(confusion_matrix_QDA, 
                              index=['Type_2', 'Type_5', 'Type_6'], 
                              columns=['Pred_Type_2', 'Pred_Type_5', 'Pred_Type_6'])

print('\n############### Quadratic Discriminant Analysis ###############')
print('Relatório de Classificação:\n', classification_report_QDA)
print('Matriz de Confusão:\n', confusion_matrix_QDA_df)
# Out:
# ############### Logistic Regression ###############
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.76      0.66      0.70       421
#            1       0.77      0.77      0.77       584
#            2       0.90      0.97      0.93       648
#
#     accuracy                           0.82      1653
#    macro avg       0.81      0.80      0.80      1653
# weighted avg       0.82      0.82      0.82      1653
#
# Matriz de Confusão:
#          Pred_Type_2  Pred_Type_5  Pred_Type_6
# Type_2          278          120           23
# Type_5           85          450           49
# Type_6            5           15          628
#
# ############### Linear Discriminant Analysis ###############
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.79      0.59      0.68       421
#            1       0.71      0.85      0.77       584
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Logistic Regression:</b><br>
#     <span>Logistic Regression (LR) teve uma accuracy de 0.82, um resultado bom, mas apresentou uma diferença maior entre as classes, com dificuldades para prever a classe Type_2, que teve apenas 0.66 de recall.</span>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>LDA:</b><br>
#     <span>Linear Discriminant Analysis (LDA) teve uma accuracy de 0.81, mas o seu principal problema foi o recall baixo para Type_2 (0.59), o que significa que o modelo teve mais dificuldades para identificar corretamente esta classe.</span>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>QDA:</b><br>
#     <span>Quadratic Discriminant Analysis (QDA) foi o modelo com melhor desempenho global, com uma accuracy de 0.82 e métricas equilibradas em todas as classes. Foi o modelo que apresentou o maior equilíbrio entre a precisão e o recall para todas as classes, especialmente para Type_2, que foi uma das classes mais difíceis de prever corretamente nos outros modelos.</span>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Em suma:</b><br>
#     <span>QDA é o melhor modelo, com maior precisão e consistência em todas as classes.</span><br>
#     <span>Logistic Regression também é uma boa escolha, mas tem mais dificuldade em distinguir entre Type_2 e Type_5.</span><br>
#     <span>LDA funciona bem em geral, mas é menos eficaz na identificação da classe Type_2.</span>
# </div>

# %% [markdown]
# ### Resampling Method: K-fold Cross Validation

# %% [markdown]
# Como neste método fazemos várias divisões do datasample, é importante garantir que a distribuição para cada label é semelhante (uma vez que não o é no conjunto de dados originais), daí a utilização do StratifiedKFold e não do Kfold comum.

# %%
# Normalizar os dados
scaler = StandardScaler() # Inicializar o StandardScaler
Xstd = scaler.fit_transform(X) # Normalizar toda a amostra X, posteriormente dividida em treino/teste com o método K-Fold Cross Validation

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Inicializar o StratifiedKFold para k=5
k = 5  # Define o número de splits
kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

##########################LR##########################
# Previsões com os vários folds
y_pred_LR = cross_val_predict(logrLR, Xstd, y, cv=kf)

# Avaliação do desempenho do modelo
classification_report_LR = classification_report(y, y_pred_LR)
confusion_matrix_LR = confusion_matrix(y, y_pred_LR, labels=[0, 1, 2])

# Converter a matriz para um DataFrame para mostrar as classes
confusion_matrix_LR_df = pd.DataFrame(confusion_matrix_LR, 
                                      index=['Type_2', 'Type_5', 'Type_6'], 
                                      columns=['Pred_Type_2', 'Pred_Type_5', 'Pred_Type_6'])

print('\n############### Logistic Regression ###############')
print('Relatório de Classificação:\n', classification_report_LR)
print('Matriz de Confusão:\n', confusion_matrix_LR_df)


##########################LDA##########################
# Previsões com os vários folds
y_pred_LDA = cross_val_predict(logrLDA, Xstd, y, cv=kf)

# Avaliação do desempenho do modelo
classification_report_LDA = classification_report(y, y_pred_LDA)
confusion_matrix_LDA = confusion_matrix(y, y_pred_LDA, labels=[0, 1, 2])

# Converter a matriz para um DataFrame para mostrar as classes
confusion_matrix_LDA_df = pd.DataFrame(confusion_matrix_LDA, 
                                       index=['Type_2', 'Type_5', 'Type_6'], 
                                       columns=['Pred_Type_2', 'Pred_Type_5', 'Pred_Type_6'])

print('\n############### Linear Discriminant Analysis ###############')
print('Relatório de Classificação:\n', classification_report_LDA)
print('Matriz de Confusão:\n', confusion_matrix_LDA_df)


##########################QDA##########################
# Previsões com os vários folds
y_pred_QDA = cross_val_predict(logrQDA, Xstd, y, cv=kf)

# Avaliação do desempenho do modelo
classification_report_QDA = classification_report(y, y_pred_QDA)
confusion_matrix_QDA = confusion_matrix(y, y_pred_QDA, labels=[0, 1, 2])

# Converter a matriz para um DataFrame para mostrar as classes
confusion_matrix_QDA_df = pd.DataFrame(confusion_matrix_QDA, 
                                       index=['Type_2', 'Type_5', 'Type_6'], 
                                       columns=['Pred_Type_2', 'Pred_Type_5', 'Pred_Type_6'])

print('\n############### Quadratic Discriminant Analysis ###############')
print('Relatório de Classificação:\n', classification_report_QDA)
print('Matriz de Confusão:\n', confusion_matrix_QDA_df)
# Out:
# ############### Logistic Regression ###############
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.74      0.66      0.70      1404
#            1       0.77      0.76      0.77      1944
#            2       0.90      0.97      0.94      2160
#
#     accuracy                           0.82      5508
#    macro avg       0.80      0.80      0.80      5508
# weighted avg       0.81      0.82      0.81      5508
#
# Matriz de Confusão:
#          Pred_Type_2  Pred_Type_5  Pred_Type_6
# Type_2          923          403           78
# Type_5          311         1485          148
# Type_6           15           49         2096
#
# ############### Linear Discriminant Analysis ###############
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.77      0.60      0.67      1404
#            1       0.70      0.84      0.76      1944
# ...

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Inicializar o StratifiedKFold para k=10
k = 10  # Define o número de splits
kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

##########################LR##########################
# Previsões com os vários folds
y_pred_LR = cross_val_predict(logrLR, Xstd, y, cv=kf)

# Avaliação do desempenho do modelo
classification_report_LR = classification_report(y, y_pred_LR)
confusion_matrix_LR = confusion_matrix(y, y_pred_LR, labels=[0, 1, 2])

# Converter a matriz para um DataFrame para mostrar as classes
confusion_matrix_LR_df = pd.DataFrame(confusion_matrix_LR, 
                                      index=['Type_2', 'Type_5', 'Type_6'], 
                                      columns=['Pred_Type_2', 'Pred_Type_5', 'Pred_Type_6'])

print('\n############### Logistic Regression ###############')
print('Relatório de Classificação:\n', classification_report_LR)
print('Matriz de Confusão:\n', confusion_matrix_LR_df)


##########################LDA##########################
# Previsões com os vários folds
y_pred_LDA = cross_val_predict(logrLDA, Xstd, y, cv=kf)

# Avaliação do desempenho do modelo
classification_report_LDA = classification_report(y, y_pred_LDA)
confusion_matrix_LDA = confusion_matrix(y, y_pred_LDA, labels=[0, 1, 2])

# Converter a matriz para um DataFrame para mostrar as classes
confusion_matrix_LDA_df = pd.DataFrame(confusion_matrix_LDA, 
                                       index=['Type_2', 'Type_5', 'Type_6'], 
                                       columns=['Pred_Type_2', 'Pred_Type_5', 'Pred_Type_6'])

print('\n############### Linear Discriminant Analysis ###############')
print('Relatório de Classificação:\n', classification_report_LDA)
print('Matriz de Confusão:\n', confusion_matrix_LDA_df)


##########################QDA##########################
# Previsões com os vários folds
y_pred_QDA = cross_val_predict(logrQDA, Xstd, y, cv=kf)

# Avaliação do desempenho do modelo
classification_report_QDA = classification_report(y, y_pred_QDA)
confusion_matrix_QDA = confusion_matrix(y, y_pred_QDA, labels=[0, 1, 2])

# Converter a matriz para um DataFrame para mostrar as classes
confusion_matrix_QDA_df = pd.DataFrame(confusion_matrix_QDA, 
                                       index=['Type_2', 'Type_5', 'Type_6'], 
                                       columns=['Pred_Type_2', 'Pred_Type_5', 'Pred_Type_6'])

print('\n############### Quadratic Discriminant Analysis ###############')
print('Relatório de Classificação:\n', classification_report_QDA)
print('Matriz de Confusão:\n', confusion_matrix_QDA_df)
# Out:
# ############### Logistic Regression ###############
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.74      0.66      0.70      1404
#            1       0.77      0.76      0.77      1944
#            2       0.90      0.97      0.94      2160
#
#     accuracy                           0.82      5508
#    macro avg       0.80      0.80      0.80      5508
# weighted avg       0.81      0.82      0.82      5508
#
# Matriz de Confusão:
#          Pred_Type_2  Pred_Type_5  Pred_Type_6
# Type_2          929          398           77
# Type_5          315         1482          147
# Type_6           14           49         2097
#
# ############### Linear Discriminant Analysis ###############
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.77      0.60      0.67      1404
#            1       0.70      0.84      0.76      1944
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Logistic Regression:</b><br>
#     <span>Logistic Regression (LR) teve uma accuracy de 0.82, um resultado bom, mas apresentou uma diferença maior entre as classes, com dificuldades para prever a classe Type_2, que teve apenas 0.66 de recall.</span>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>LDA:</b><br>
#     <span>Linear Discriminant Analysis (LDA) teve uma accuracy de 0.81, um valor igualmente positivo. No entanto, o principal problema é também o baixo recall registado para Type_2 (0.60), o que significa que o modelo teve mais dificuldades para identificar corretamente esta classe.</span>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>QDA:</b><br>
#     <span>Quadratic Discriminant Analysis (QDA) teve uma accuracy de 0.82, em linha com os valores registados para os outros dois modelos. No entanto, apresenta valores de recall mais equilibrados, especialmente para a classe Type_2, para a qual foram detetados problemas anteriormente.</span>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>k=5/k=10:</b><br>
#     <span>Para todos os modelos, os valores registados para k=5 e k=10 são muito idênticos, não havendo praticamente diferenças, principalmente diferenças significativas, entre os dois valores.</span>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Em suma:</b><br>
#     <span>Quadratic Discriminant Analysis (QDA) foi o modelo com melhor desempenho global. Foi registado uma accuracy de 0.82, valores dentro do normal para os 3 modelos, mas leva a vantagem com os valores de recall, equilibrados e positivos para todas as classes, ainda que se destaque claramente</span>
# </div>

# %% [markdown]
# ### Resampling Method: LOOCV - Leave One Out Cross Validation

# %% [markdown]
# #### Avaliação do modelo

# %%
from sklearn.model_selection import LeaveOneOut, cross_val_predict, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix

# Inicializar o Leave-One-Out
cv = LeaveOneOut()

########################## Logistic Regression ##########################
print('\n############### Logistic Regression - LOOCV ###############')

# Acurácia e desvio padrão com LOOCV
scores_lr = cross_val_score(logrLR, Xstd, y, scoring='accuracy', cv=cv)
print('Mean Accuracy for Logistic Regression: %.3f (%.3f)' % (np.mean(scores_lr), np.std(scores_lr)))

# Previsões com LOOCV para outras métricas
y_pred_LR = cross_val_predict(logrLR, Xstd, y, cv=cv)

# Avaliação do desempenho do modelo (com todas as métricas)
classification_report_LR = classification_report(y, y_pred_LR, target_names=['Type_2', 'Type_5', 'Type_6'])
confusion_matrix_LR = confusion_matrix(y, y_pred_LR, labels=[0, 1, 2])

confusion_matrix_LR_df = pd.DataFrame(confusion_matrix_LR, index=['True_Type_2', 'True_Type_5', 'True_Type_6'], columns=['Pred_Type_2', 'Pred_Type_5', 'Pred_Type_6'])

# Mostrar os resultados
print('Relatório de Classificação:\n', classification_report_LR)
print('Matriz de Confusão:\n', confusion_matrix_LR_df)


########################## Linear Discriminant Analysis ##########################
print('\n############### Linear Discriminant Analysis - LOOCV ###############')

# Acurácia e desvio padrão com LOOCV
scores_lda = cross_val_score(logrLDA, Xstd, y, scoring='accuracy', cv=cv)
print('\nMean Accuracy for LDA: %.3f (%.3f)' % (np.mean(scores_lda), np.std(scores_lda)))

# Previsões com LOOCV para outras métricas
y_pred_LDA = cross_val_predict(logrLDA, Xstd, y, cv=cv)

# Avaliação do desempenho do modelo
classification_report_LDA = classification_report(y, y_pred_LDA, target_names=['Type_2', 'Type_5', 'Type_6'])
confusion_matrix_LDA = confusion_matrix(y, y_pred_LDA, labels=[0, 1, 2])

confusion_matrix_LDA_df = pd.DataFrame(confusion_matrix_LDA, index=['True_Type_2', 'True_Type_5', 'True_Type_6'], columns=['Pred_Type_2', 'Pred_Type_5', 'Pred_Type_6'])

# Mostrar os resultados
print('Relatório de Classificação:\n', classification_report_LDA)
print('Matriz de Confusão:\n', confusion_matrix_LDA_df)


########################## Quadratic Discriminant Analysis ##########################
print('\n############### Quadratic Discriminant Analysis - LOOCV ###############')

# Acurácia e desvio padrão com LOOCV
scores_qda = cross_val_score(logrQDA, Xstd, y, scoring='accuracy', cv=cv)
print('\nMean Accuracy for QDA: %.3f (%.3f)' % (np.mean(scores_qda), np.std(scores_qda)))

# Previsões com LOOCV para outras métricas
y_pred_QDA = cross_val_predict(logrQDA, Xstd, y, cv=cv)

# Avaliação do desempenho do modelo
classification_report_QDA = classification_report(y, y_pred_QDA, target_names=['Type_2', 'Type_5', 'Type_6'])
confusion_matrix_QDA = confusion_matrix(y, y_pred_QDA, labels=[0, 1, 2])

confusion_matrix_QDA_df = pd.DataFrame(confusion_matrix_QDA, index=['True_Type_2', 'True_Type_5', 'True_Type_6'], columns=['Pred_Type_2', 'Pred_Type_5', 'Pred_Type_6'])

# Mostrar os resultados
print('Relatório de Classificação:\n', classification_report_QDA)
print('Matriz de Confusão:\n', confusion_matrix_QDA_df)
# Out:
# ############### Logistic Regression - LOOCV ###############
# Mean Accuracy for Logistic Regression: 0.818 (0.386)
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#       Type_2       0.74      0.66      0.70      1404
#       Type_5       0.77      0.76      0.76      1944
#       Type_6       0.90      0.97      0.94      2160
#
#     accuracy                           0.82      5508
#    macro avg       0.80      0.80      0.80      5508
# weighted avg       0.81      0.82      0.81      5508
#
# Matriz de Confusão:
#               Pred_Type_2  Pred_Type_5  Pred_Type_6
# True_Type_2          924          405           75
# True_Type_5          313         1484          147
# True_Type_6           15           49         2096
#
# ############### Linear Discriminant Analysis - LOOCV ###############
#
# Mean Accuracy for LDA: 0.804 (0.397)
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Logistic Regression:</b><br>
#     <span>O modelo de Logistic Regression apresenta um bom desempenho geral, com uma accuracy de 0.818.</span><br>
#     <span>A classe Type_6 é claramente a mais fácil de prever, com uma precisão de 0.90 e um recall de 0.97, o que indica que o modelo classifica corretamente quase todos os exemplos desta classe.</span><br>
#     <span>O desempenho geral é bom, mas esta confusão entre Type_2 e Type_5 mostra que o modelo tem dificuldades em separar estas classes de forma clara.</span>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>LDA:</b><br>
#     <span>O modelo de LDA apresenta uma accuracy de 0.804, ligeiramente inferior ao de Logistic Regression.</span><br>
#     <span>A classe Type_6 continua a ser a mais bem classificada, com uma precisão de 0.94 e um recall de 0.91, mostrando um desempenho consistente em relação ao Logistic Regression.</span><br>
#     <span>No entanto, o LDA apresenta uma maior confusão entre as classes Type_2 e Type_5, com Type_2 a ser incorretamente classificada como Type_5 em 516 casos. Este é um aumento significativo em comparação ao modelo de Logistic Regression.</span><br>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>QDA:</b><br>
#     <span>O modelo de QDA apresenta a melhor accuracy (0.821) e equilíbrio entre classes.</span><br>
#     <span>Type_6 continua a ser a classe mais fácil de prever, com uma precisão de 0.84 e um recall de 0.97, mostrando uma boa consistência em todos os modelos.</span><br>
#     <span>A principal vantagem do QDA é a sua capacidade de lidar melhor com a Type_2, com uma precisão de 0.79 e um recall de 0.74, sendo este o melhor desempenho entre os três modelos para esta classe. Além disso, o QDA reduz a confusão entre Type_2 e Type_5 em comparação aos outros modelos, com apenas 257 exemplos da Type_2 incorretamente classificados como Type_5.</span><br>
#     <span>Type_5, por outro lado, ainda apresenta alguns problemas de confusão, com 256 exemplos mal classificados como Type_2, embora o recall desta classe seja aceitável (0.71).</span>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Em suma:</b><br>
#     <span>O melhor modelo é o QDA:</span><br>
#     <ul>
#         <li>Apresenta melhor accuracy e um equilíbrio entre precisão e recall para as três classes.</li>
#         <li>A classe Type_2, que foi a mais difícil de prever corretamente nos outros modelos, teve um desempenho notavelmente melhor com o QDA, com uma precisão de 0.79 e um recall de 0.74. O QDA minimizou a confusão entre Type_2 e Type_5, ao contrário do LDA, que teve grandes dificuldades em separar estas duas classes.</li>
#         <li>Apesar de o QDA também apresentar alguma confusão entre Type_5 e Type_6, o modelo conseguiu melhorar o equilíbrio entre as classes em comparação com o Logistic Regression e o LDA.</li>
#     </ul>
#     <span>Logistic Regression continua a ser uma boa alternativa, especialmente se precisarmos de um modelo mais simples e fácil de interpretar, já que o seu desempenho foi bastante semelhante ao QDA, com uma accuracy de 0.818. No entanto, o QDA mostra-se superior no que diz respeito ao tratamento das classes mais difíceis</span>
# </div>

# %% [markdown]
# ### Resampling Method: Bootstrap

# %%
from sklearn.metrics import accuracy_score

n_samples = len(X)  # Total de amostra do dataset
bootstrap_range = [25,50,100] # Número de iterações
lr_accuracies_means = []
lr_accuracies_stds = []

# For cycle sobre o bootstrap_range
for n in bootstrap_range:
    print(f"Bootstrap iteration with {n} samples:")

    lr_accuracies_n = []

    # Realizar 'n' iterações de bootstrap
    for i in range(n):
        # Criar a amostra com bootstrapping (with replacement)
        train_indices = np.random.choice(n_samples, size=n_samples, replace=True)
        X_train_set = X.iloc[train_indices]
        Y_train_set = y.iloc[train_indices]
        
        # Criar a amostra de teste (os que não foram selecionados)
        test_indices = list(set(range(n_samples)) - set(train_indices))
        X_test_set = X.iloc[test_indices]
        y_test_set = y.iloc[test_indices]

        # Treinar o modelo de regressão logística
        logrLR.fit(X_train_set, Y_train_set)
        
        # Fazer previsões no conjunto de teste
        y_pred_lr = logrLR.predict(X_test_set)
        
        # Calcular a acurácia
        lr_accuracy = accuracy_score(y_test_set, y_pred_lr)
        lr_accuracies_n.append(lr_accuracy)
        
    # Armazenar a média e desvio padrão das acurácias para cada n
    lr_accuracies_means.append(np.mean(lr_accuracies_n))
    lr_accuracies_stds.append(np.std(lr_accuracies_n))

plt.plot(bootstrap_range, lr_accuracies_means, label="Mean Accuracy")
plt.plot(bootstrap_range, lr_accuracies_stds, label="Std Deviation", linestyle="--")
plt.xlabel("Number of Bootstrap Samples")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# Bootstrap iteration with 25 samples:
# Bootstrap iteration with 50 samples:
# Bootstrap iteration with 100 samples:

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Logistic Regression:</b><br>
#     <span>Para os valores de k testados, a accuracy mantém-se estável, mas apresenta o valor mais alto para k = 25..</span><br>
# </div>

# %% [markdown]
# #### Avaliação do modelo

# %%
n_samples = len(Xstd)  # Total de amostra do dataset

# Definir o número de bootstrap samples
n_bootstrap = 25

# Criar listas para guardar os valores de accuracy e matrizes de confusão
lr_accuracies = []
lda_accuracies = []
qda_accuracies = []

lr_confusion_matrices = []
lda_confusion_matrices = []
qda_confusion_matrices = []

lr_reports = []
lda_reports = []
qda_reports = []

# Converter o conjunto de dados previamente normalizado (para o K-Fold Cross Validation) num dataframe
Xstd_df = pd.DataFrame(Xstd, index=X.index, columns=X.columns)

# Fazer loop a todas as bootstrap samples
for i in range(n_bootstrap):
    # Criar a amostra com bootstrapping (with replacement)
    train_indices = np.random.choice(n_samples, size=n_samples, replace=True)
    X_train_set = Xstd_df.iloc[train_indices]
    Y_train_set = y.iloc[train_indices]
    
    # Criar a amostra de teste (os que não foram selecionados)
    test_indices = list(set(range(n_samples)) - set(train_indices))
    X_test_set = Xstd_df.iloc[test_indices]
    y_test_set = y.iloc[test_indices]
    
    # Logistic Regression (LR)
    logrLR.fit(X_train_set, Y_train_set)
    y_pred_lr = logrLR.predict(X_test_set)
    lr_accuracy = accuracy_score(y_test_set, y_pred_lr)
    lr_accuracies.append(lr_accuracy)
    lr_report = classification_report(y_test_set, y_pred_lr, target_names=['Type_2', 'Type_5', 'Type_6'], output_dict=True)
    lr_reports.append(lr_report)
    lr_confusion_matrices.append(confusion_matrix(y_test_set, y_pred_lr, labels=[0, 1, 2]))

    # Linear Discriminant Analysis (LDA)
    logrLDA.fit(X_train_set, Y_train_set)
    y_pred_lda = logrLDA.predict(X_test_set)
    lda_accuracy = accuracy_score(y_test_set, y_pred_lda)
    lda_accuracies.append(lda_accuracy)
    lda_report = classification_report(y_test_set, y_pred_lda, target_names=['Type_2', 'Type_5', 'Type_6'], output_dict=True)
    lda_reports.append(lda_report)
    lda_confusion_matrices.append(confusion_matrix(y_test_set, y_pred_lda, labels=[0, 1, 2]))
    
    # Quadratic Discriminant Analysis (QDA)
    logrQDA.fit(X_train_set, Y_train_set)
    y_pred_qda = logrQDA.predict(X_test_set)
    qda_accuracy = accuracy_score(y_test_set, y_pred_qda)
    qda_accuracies.append(qda_accuracy)
    qda_report = classification_report(y_test_set, y_pred_qda, target_names=['Type_2', 'Type_5', 'Type_6'], output_dict=True)
    qda_reports.append(qda_report)
    qda_confusion_matrices.append(confusion_matrix(y_test_set, y_pred_qda, labels=[0, 1, 2]))

# Calcular a média e o desvio padrão de accuracy para cada modelo
avg_lr_accuracy = np.mean(lr_accuracies)
std_lr_accuracy = np.std(lr_accuracies)

avg_lda_accuracy = np.mean(lda_accuracies)
std_lda_accuracy = np.std(lda_accuracies)

avg_qda_accuracy = np.mean(qda_accuracies)
std_qda_accuracy = np.std(qda_accuracies)

# Função para calcular a média de um classification report
def average_classification_report(reports):
    # Initialize an empty dictionary to store cumulative sums
    avg_report = {
        'Type_2': {'precision': 0, 'recall': 0, 'f1-score': 0, 'support': 0},
        'Type_5': {'precision': 0, 'recall': 0, 'f1-score': 0, 'support': 0},
        'Type_6': {'precision': 0, 'recall': 0, 'f1-score': 0, 'support': 0},
        'macro avg': {'precision': 0, 'recall': 0, 'f1-score': 0, 'support': 0},
        'weighted avg': {'precision': 0, 'recall': 0, 'f1-score': 0, 'support': 0}
    }
    
    # Sum the reports
    for report in reports:
        for key in avg_report.keys():
            for metric in ['precision', 'recall', 'f1-score', 'support']:
                avg_report[key][metric] += report[key][metric]
    
    # Calculate the average by dividing by the number of reports
    num_reports = len(reports)
    for key in avg_report.keys():
        for metric in ['precision', 'recall', 'f1-score', 'support']:
            avg_report[key][metric] /= num_reports

    return avg_report

# Calcular a média das matrizes de confusão e classification reports
avg_lr_confusion_matrix = np.mean(lr_confusion_matrices, axis=0)
avg_lda_confusion_matrix = np.mean(lda_confusion_matrices, axis=0)
avg_qda_confusion_matrix = np.mean(qda_confusion_matrices, axis=0)

avg_lr_report = average_classification_report(lr_reports)
avg_lda_report = average_classification_report(lda_reports)
avg_qda_report = average_classification_report(qda_reports)

# Print the results
print(f'Average Logistic Regression Accuracy: {avg_lr_accuracy:.4f}, Standard Deviation: {std_lr_accuracy:.4f}')
print(f'Average LDA Accuracy: {avg_lda_accuracy:.4f}, Standard Deviation: {std_lda_accuracy:.4f}')
print(f'Average QDA Accuracy: {avg_qda_accuracy:.4f}, Standard Deviation: {std_qda_accuracy:.4f}')

# Mostrar as matrizes de confusão médias
print(f'Average Logistic Regression Confusion Matrix:\n{avg_lr_confusion_matrix}')
print(f'Average LDA Confusion Matrix:\n{avg_lda_confusion_matrix}')
print(f'Average QDA Confusion Matrix:\n{avg_qda_confusion_matrix}')

# Mostrar os classification reports médios
print(f'Average Logistic Regression Classification Report:\n{avg_lr_report}')
print(f'Average LDA Classification Report:\n{avg_lda_report}')
print(f'Average QDA Classification Report:\n{avg_qda_report}')
# Out:
# Average Logistic Regression Accuracy: 0.8158, Standard Deviation: 0.0069
# Average LDA Accuracy: 0.8040, Standard Deviation: 0.0077
# Average QDA Accuracy: 0.8173, Standard Deviation: 0.0069
# Average Logistic Regression Confusion Matrix:
# [[342.48 147.96  27.56]
#  [119.76 550.6   54.72]
#  [  5.64  19.32 767.8 ]]
# Average LDA Confusion Matrix:
# [[310.72 189.6   17.68]
#  [ 86.32 605.    33.76]
#  [  8.6   63.16 721.  ]]
# Average QDA Confusion Matrix:
# [[382.44  95.44  40.12]
#  [ 97.48 514.08 113.52]
#  [  7.2   18.2  767.36]]
# Average Logistic Regression Classification Report:
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Logistic Regression:</b><br>
#     <span>Os valores de accuracy registados são elevados (0.8161) e o desvio padrão é mínimo. Os valores de recall apresentam alguma oscilação, com foco para os valores mais baixos para o type_2, mas consideravelmente superiores para o type_6.</span><br>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>LDA:</b><br>
#         <span>Os valores de accuracy registados são elevados (0.8048), ainda que ligeiramente inferiores comparativamente ao modelo anterior, e o desvio padrão é mínimo, mas ligeiramente superior. Relativamente ao recall, apresenta valores particularmente baixos para o type_2.</span><br>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>QDA:</b><br>
#     <span>Os valores de accuracy registados são elevados (0.8193) e o desvio padrão é mínimo. Em comparação com os dois modelos anteriores, apresenta um valor de recall para o type_2, mais crítico, superior, e maior equilíbrio entre os valores.</span><br>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Em suma:</b><br>
#     <span>Os modelos apresentam um rendimento semelhante, com valores de accuracy altos e de desvio padrão muito baixos e as diferenças são mínimas..</span><br>
#     <span>Ainda assim, o melhor modelo é o QDA porque:</span><br>
#     <ul>
#         <li>Apresenta a maior accuracy (0.8193), indicando uma boa capacidade de previsão, apesar de a diferença ser mínima.</li>
#         <li>Apresenta um desvio padrão muito baixo accuracy (0.0083), ainda que não seja o valor mais baixo, é uma diferença residual.</li>
#         <li>Apresenta valores de recall relativamente altos e equilibrados, destacando-se particularmente pelo recall para ao type_2, crítico nos outros dois modelos</li>
#     </ul>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <span><b>Melhor modelo:</b> Quadratic Discriminant Analysis (QDA)</span><br>
#     <span><b>Melhor técnica de amostragem:</b> Leave-One-Out Cross-Validation (LOOCV)</span><br><br>
#     <span>Obteve uma accuracy de 0.821 e um bom equilíbrio entre as classes, especialmente na capacidade de capturar corretamente a classe Type_6 (recall de 0.97) e a classe Type_2 (recall de 0.74).</span><br>
#     <span>O QDA teve os melhores resultados nas diferentes técnicas de amostragem, mas o LOOCV garantiu que o modelo fosse testado no máximo de amostras possíveis, tornando a avaliação mais precisa e detalhada, apesar do elevado custo computacional.</span><br>
#     <span>O QDA funcionou melhor devido ao facto de ser um modelo não linear, que pode capturar melhor as relações entre as variáveis quando as classes são distribuídas de forma não linear. Pode ser observado especialmente na classe Type_2, que foi mais difícil de capturar corretamente para os outros modelos (LR e LDA).</span>
# </div>

# %% [markdown]
# ## Seleção das Features

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <span><b>Modelo:</b> Logistic Regression (LR)</span><br>
#     <span><b>Melhor técnica de amostragem:</b> Cross-Validation (K=5 ou K=10)</span><br><br>
#     <span>Obteve uma accuracy de 0.82 (similar ao Holdout) tanto para K=5 e K=10, mas com maior confiabilidade nos resultados devido ao uso de múltiplas partições para treino e teste. Além disso, conseguiu equilibrar bem o desempenho nas três classes.</span><br>
#     <span>Type_6 continua a ser a classe mais bem classificada, com precisão de 0.90 e recall de 0.97.</span><br>
#     <span>A confusão entre Type_2 e Type_5 é notável, como no Holdout, mas como a avaliação foi feita em vários conjuntos de dados, garante maior confiabilidade nos resultados.</span>
# </div>

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.linear_model import RidgeClassifier
from sklearn.model_selection import cross_val_score, KFold

# Definir valores de alpha a testar
alpha_ridge = [0, 1e-8, 1e-4, 1e-3, 1e-2, 1, 5, 10, 20, 25]

# Lista para armazenar os resultados da acurácia
accuracy_values = []

# Inicializar K-Fold Cross Validation com k=10
kf = KFold(n_splits=10, shuffle=True, random_state=42)

for alpha in alpha_ridge:
    # Inicializa o modelo RidgeClassifier com o valor de alpha atual
    ridge_model = RidgeClassifier(alpha=alpha)
    
    # Aplicar cross-validation e calcular a média da acurácia
    accuracies = cross_val_score(ridge_model, Xstd, y, cv=kf, scoring='accuracy')
    accuracy_mean = np.mean(accuracies)
    
    # Armazenar a média de acurácia
    accuracy_values.append(accuracy_mean)

# Encontrar a maior acurácia e o índice correspondente
max_accuracy = max(accuracy_values)
max_accuracy_index = accuracy_values.index(max_accuracy)
best_alpha = alpha_ridge[max_accuracy_index]
print(f"Maior Accuracy: {max_accuracy:.3f} para alpha = {best_alpha}")

# Plotar o desempenho do modelo para diferentes valores de alpha
plt.figure(figsize=(10, 6))
sns.lineplot(x=np.log10(alpha_ridge), y=accuracy_values, marker='o', palette="dark")
plt.title('Desempenho do modelo Ridge para os diferentes valores de Alpha (Cross-Validation K=10)')
plt.xlabel('log10(alpha)')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
# Out:
# Maior Accuracy: 0.771 para alpha = 25

# %%
# Definir o melhor alpha encontrado em cima
best_alpha = 25 

# Inicializar o modelo RidgeClassifier com o melhor alpha
best_ridge_model = RidgeClassifier(alpha=best_alpha)

# Usar Cross-Validation com K=10 para fazer previsões
kf = KFold(n_splits=10, shuffle=True, random_state=42)

# Fazer as previsões com K-Fold
y_pred = cross_val_predict(best_ridge_model, Xstd, y, cv=kf)

# Calcular a acurácia média utilizando cross_val_score
mean_accuracy = cross_val_score(best_ridge_model, Xstd, y, cv=kf, scoring='accuracy').mean()
print(f"Mean Accuracy: {mean_accuracy:.3f}")

# Calcular a matriz de confusão
conf_matrix = confusion_matrix(y, y_pred, labels=[0, 1, 2])

# Calcular o relatório de classificação (precisão, recall, f1-score)
class_report = classification_report(y, y_pred)

# Mostrar a matriz de confusão e o relatório de classificação
conf_matrix_df = pd.DataFrame(conf_matrix, 
                              index=['True_Type_2', 'True_Type_5', 'True_Type_6'], 
                              columns=['Pred_Type_2', 'Pred_Type_5', 'Pred_Type_6'])

print("\nRelatório de Classificação:\n", class_report)
print("Matriz de Confusão:\n", conf_matrix_df)

# Treinar o modelo no conjunto completo para acessar os coeficientes
best_ridge_model.fit(Xstd, y)

# Acessar os coeficientes do modelo treinado
coefficients = best_ridge_model.coef_[0]

# Criar um DataFrame para visualização dos coeficientes
coef_df = pd.DataFrame({'Atributo': X.columns, 'Coeficiente': coefficients})

# Ordenar os coeficientes em ordem crescente
sorted_coef_df = coef_df.sort_values(by='Coeficiente')

# Exibir os atributos com menor peso
print("Atributos com Menor Peso:")
print(sorted_coef_df.head(10))

# Plotar os coeficientes
plt.figure(figsize=(12, 8))
sns.barplot(x='Coeficiente', y='Atributo', data=sorted_coef_df, palette='viridis')
plt.title('Coeficientes do Modelo Ridge')
plt.xlabel('Coeficiente')
plt.ylabel('Atributo')
plt.show()
# Out:
# Mean Accuracy: 0.771
#
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.69      0.57      0.62      1404
#            1       0.71      0.70      0.71      1944
#            2       0.86      0.97      0.91      2160
#
#     accuracy                           0.77      5508
#    macro avg       0.75      0.74      0.75      5508
# weighted avg       0.76      0.77      0.76      5508
#
# Matriz de Confusão:
#               Pred_Type_2  Pred_Type_5  Pred_Type_6
# True_Type_2          796          513           95
# True_Type_5          329         1360          255
# True_Type_6           30           40         2090
# Atributos com Menor Peso:
#                       Atributo  Coeficiente
# 15             Wilderness_Area    -0.123668
# 6              Shadow_Index_9h    -0.114952
# 4   Vertical_Distance_To_Water    -0.090270
# 1            Slope_Orientation    -0.073558
# 2                        Slope    -0.058630
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <span>Após a atribuição de menor peso em alguns atributos preditivos, o Ridge teve um desempenho inferior em comparação com a Regressão Logística aplicada no Cross-validation (k=10), onde a accuracy (0.771) e as restantes métricas foram inferiores.</span><br>
# </div>

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import LassoCV, Lasso

alphas = [0, 1e-8, 1e-4, 1e-3, 1e-2, 1, 5, 10, 20, 25]

# Initialize LassoCV to find the best alpha
lasso_cv = LassoCV(alphas=alphas, cv=5, max_iter=10000)

# Fit LassoCV to the standardized data
lasso_cv.fit(Xstd, y)

# Get the best alpha
best_alpha = lasso_cv.alpha_
print(f'Best alpha: {best_alpha}')

# Retrieve coefficients for each alpha tested by LassoCV
coefs = []
for alpha in lasso_cv.alphas_:
    lasso = Lasso(alpha=alpha, max_iter=10000)
    lasso.fit(Xstd, y)
    coefs.append(lasso.coef_)

# Convert coefficients to a NumPy array for easier handling
coefs = np.array(coefs)

# Plot the coefficients across alpha values
ax = plt.gca()
ax.plot(lasso_cv.alphas_ * 2, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
plt.title('Lasso Coefficients as a Function of Alpha')
plt.show()
# Out:
# Best alpha: 0.001

# %%
# Usar o melhor c (1/alpha) na LR com penalty L1, usando o Lasso na classificação
best_lasso_model = LR(penalty='l1', C=1/best_alpha, solver='liblinear')

# Usar Cross-Validation com K=10 para fazer previsões
kf = KFold(n_splits=10, shuffle=True, random_state=42)

# Fazer as previsões com K-Fold
y_pred = cross_val_predict(best_lasso_model, Xstd, y, cv=kf)

# Calcular a acurácia média utilizando cross_val_score
mean_accuracy = cross_val_score(best_lasso_model, Xstd, y, cv=kf, scoring='accuracy').mean()
print(f"Mean Accuracy: {mean_accuracy:.3f}")

# Calcular a matriz de confusão
conf_matrix = confusion_matrix(y, y_pred, labels=np.unique(y))

# Calcular o relatório de classificação (precisão, recall, f1-score)
class_report = classification_report(y, y_pred)

# Mostrar a matriz de confusão e o relatório de classificação
conf_matrix_df = pd.DataFrame(conf_matrix, 
                              index=[f'True_{label}' for label in np.unique(y)], 
                              columns=[f'Pred_{label}' for label in np.unique(y)])

print("\nRelatório de Classificação:\n", class_report)
print("Matriz de Confusão:\n", conf_matrix_df)

# 3. Treinar o modelo no conjunto completo para acessar os coeficientes
best_lasso_model.fit(Xstd, y)

# Acessar os coeficientes do modelo treinado
coefficients = best_lasso_model.coef_[0]

# Criar um DataFrame para visualização dos coeficientes
coef_df = pd.DataFrame({'Atributo': X.columns, 'Coeficiente': coefficients})

# Ordenar os coeficientes em ordem crescente
sorted_coef_df = coef_df.sort_values(by='Coeficiente')

# Exibir os atributos com menor peso
print("Atributos com Menor Peso:")
print(sorted_coef_df.head(10))

# Plotar os coeficientes
plt.figure(figsize=(12, 8))
sns.barplot(x='Coeficiente', y='Atributo', data=sorted_coef_df, palette='viridis')
plt.title('Coeficientes do Modelo Lasso')
plt.xlabel('Coeficiente')
plt.ylabel('Atributo')
plt.show()
# Out:
# Mean Accuracy: 0.819
#
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.74      0.66      0.70      1404
#            1       0.77      0.77      0.77      1944
#            2       0.91      0.97      0.94      2160
#
#     accuracy                           0.82      5508
#    macro avg       0.80      0.80      0.80      5508
# weighted avg       0.81      0.82      0.82      5508
#
# Matriz de Confusão:
#          Pred_0  Pred_1  Pred_2
# True_0     926     399      79
# True_1     312    1493     139
# True_2      17      50    2093
# Atributos com Menor Peso:
#                       Atributo  Coeficiente
# 15             Wilderness_Area    -0.673628
# 7             Shadow_Index_12h    -0.601888
# 1            Slope_Orientation    -0.463095
# 4   Vertical_Distance_To_Water    -0.282128
# 11             Rainfall_Summer    -0.108648
# 14                   Soil_Type    -0.102169
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <span>Após a modelação, o Lasso teve um desempenho praticamente idêntico em comparação com a Regressão Logística aplicada no Cross-validation (k=10), onde a accuracy (0.819) e as restantes métricas apresentam valores muito semelhantes ao modelo indicado, desenvolvido anteriormente. Apesar da capacidade de eliminar completamente as métricas, tal não se verificou</span><br>
# </div>

# %% [markdown]
# ### Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNetCV, LogisticRegression

# Define os valores de alpha e l1_ratio a serem testados
alphas = [0.001, 0.01, 0.1, 1, 10, 50]
l1_ratios = [0.1, 0.5, 0.7, 0.9, 0.95]

# Inicializa o modelo ElasticNetCV para procurar os melhores valores de alpha e l1_ratio com K=10
elastic_cv = ElasticNetCV(alphas=alphas, l1_ratio=l1_ratios, cv=10, max_iter=1000, random_state=42)

# Ajusta o ElasticNetCV aos dados padronizados
elastic_cv.fit(Xstd, y)

# Guarda os melhores valores encontrados
best_alpha = elastic_cv.alpha_
best_l1_ratio = elastic_cv.l1_ratio_
print(f"Melhor Alpha: {best_alpha}, Melhor L1_ratio: {best_l1_ratio}")

# Inicializar o modelo de Regressão Logística com elasticnet e os melhores parâmetros encontrados
best_elastic_model = LogisticRegression(penalty='elasticnet', solver='saga', C=1/best_alpha, l1_ratio=best_l1_ratio, max_iter=1000)

# Cross-Validation com K=10 para fazer previsões e calcular a média da acurácia
kf = KFold(n_splits=10, shuffle=True, random_state=42)
mean_accuracy = cross_val_score(best_elastic_model, Xstd, y, cv=kf, scoring='accuracy').mean()
print(f"Mean Accuracy: {mean_accuracy:.3f}")

# Previsões com Cross-Validation para calcular a matriz de confusão e o relatório de classificação
y_pred = cross_val_predict(best_elastic_model, Xstd, y, cv=kf)

# Matriz de Confusão
conf_matrix = confusion_matrix(y, y_pred, labels=np.unique(y))
conf_matrix_df = pd.DataFrame(conf_matrix, 
                              index=[f'True_{label}' for label in np.unique(y)], 
                              columns=[f'Pred_{label}' for label in np.unique(y)])

# Relatório de Classificação
class_report = classification_report(y, y_pred)
print("\nRelatório de Classificação:\n", class_report)
print("Matriz de Confusão:\n", conf_matrix_df)

# Treinar o modelo com todo o conjunto de dados para aceder os coeficientes
best_elastic_model.fit(Xstd, y)
coefficients = best_elastic_model.coef_[0]

# Visualização dos Coeficientes
coef_df = pd.DataFrame({'Atributo': X.columns, 'Coeficiente': coefficients})
sorted_coef_df = coef_df.sort_values(by='Coeficiente')

# Exibir os atributos com menor peso
print("Atributos com Menor Peso:")
print(sorted_coef_df.head(10))

# Plotar os coeficientes
plt.figure(figsize=(12, 8))
sns.barplot(x='Coeficiente', y='Atributo', data=sorted_coef_df, palette='viridis')
plt.title('Coeficientes do Modelo ElasticNet')
plt.xlabel('Coeficiente')
plt.ylabel('Atributo')
plt.show()
# Out:
# Melhor Alpha: 0.01, Melhor L1_ratio: 0.1
# Mean Accuracy: 0.841
#
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.82      0.66      0.73      1404
#            1       0.76      0.85      0.80      1944
#            2       0.93      0.95      0.94      2160
#
#     accuracy                           0.84      5508
#    macro avg       0.84      0.82      0.82      5508
# weighted avg       0.84      0.84      0.84      5508
#
# Matriz de Confusão:
#          Pred_0  Pred_1  Pred_2
# True_0     925     417      62
# True_1     204    1654      86
# True_2       3     106    2051
# Atributos com Menor Peso:
#                               Atributo  Coeficiente
# 15                     Wilderness_Area    -1.762279
# 6                      Shadow_Index_9h    -0.817661
# 8                     Shadow_Index_15h    -0.643523
# 1                    Slope_Orientation    -0.341232
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span>Após a modelação, o ElasticNet apresentou um desempenho superior em comparação com os modelos Ridge e Lasso, assim como à Regressão Logística no Cross-validation (k=10). O modelo alcançou uma accuracy de 0.841, além de melhorar as métricas de recall e f1-score no geral.</span><br>
# <span>Os melhores parâmetros para o ElasticNet foram alpha = 0.01 e l1_ratio = 0.1, indicando que uma combinação de regularização L1 e L2 ligeiramente mais centrada na regularização L2 conseguiu capturar melhor as relações entre as variáveis. Como resultado, o modelo ElasticNet manteve uma precisão elevada, além de uma alta capacidade de identificar a classe Type_2 (com um recall de 0.66) e um recall muito alto para Type_6 (0.95), evidenciando a sua estabilidade.</span><br>
# <span>A análise dos coeficientes revelou que os atributos com menor peso incluem Wilderness_Area, Shadow_Index_9h, Shadow_Index_15h e Slope_Orientation, indicando que esses fatores têm menor impacto nas previsões feitas pelo modelo. Este modelo mostrou-se eficiente em captar as interações e penalizar coeficientes menos influentes para maximizar o desempenho geral do modelo.</span><br>
# <span>Assim, o ElasticNet demonstrou-se vantajoso para o nosso dataset, conseguindo capturar variações entre as classes com uma regularização bem equilibrada, destacando-o como o melhor método de regularização nesta análise.</span>
# </div>
